# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
from mxnet import nd
from common import data_sets, log_utils
from ch03_polynomial_regression import PolynomialRegressionGluon

num_train = 100
num_test = 100
features, poly_features, labels = data_sets.load_data_polynomial(nd.array([1.2, -3.4, 5.6]), 5,
                                                num_train, num_test)

# %%
# just right
model = PolynomialRegressionGluon()
model.fit(poly_features[:num_train], labels[:num_train], lr=0.01, batch_size=10, epochs=100, 
          test_x=poly_features[num_train:], test_y=labels[num_train:])
# Out:
# final epoch train loss: [6.0864662e-05], test loss: [7.1525166e-05]
# weight: [[ 1.2139889 -3.397018   5.59771  ]]
# bias: [5.070166]

# %%
# under fitting
model.fit(features[:num_train], labels[:num_train], lr=0.01, batch_size=10, epochs=100,
          test_x=features[num_train:], test_y=labels[num_train:])
# Out:
# final epoch train loss: [126.67331], test loss: [178.39514]
# weight: [[20.889812]]
# bias: [1.5590755]

# %%
# over fitting
num_samll_train = 2
model.fit(poly_features[:num_samll_train], labels[:num_samll_train], lr=0.01, batch_size=10, epochs=100, 
          test_x=poly_features[num_train:], test_y=labels[num_train:])
# Out:
# final epoch train loss: [9.085531], test loss: [485.9124]
# weight: [[0.18903753 0.11726685 0.08372408]]
# bias: [0.95141226]
